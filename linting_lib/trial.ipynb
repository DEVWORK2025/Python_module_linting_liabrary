# %%
a=10
a
# Out:
# 10

# %%
name =input("enter the name")
name = ['madhuri']
char=[]

for i in name:
     if type(char)== str:
        char.append()
     else:
        print("error")
# Out:
# error

# %%
add=lambda x,y:( x+y , x-y)
add(2,3)
# Out:
# (5, -1)
