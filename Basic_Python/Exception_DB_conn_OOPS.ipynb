# %%
emp_dict = {"emp123":"asdf1234", 'int1234':'poiu0987'}

# %%
class employee:
    work = 40
    def __init__(self, emp_name, password):
        print("Initialising the class")
        if emp_name in emp_dict.keys():
            if  emp_dict[emp_name]== password:
                print("Valid user")
            else:
                print("Danger Virus")
        else:
            print("Virus")
        
    
    def calc_salry(self):
        print("Calculating salary ")

# %%
anuj=employee("int1234", 'poiu0987')
# Out:
# Initialising the class
# Valid user

# %%
ruby=employee("int1234",'asdf123')
# Out:
# Initialising the class
# Danger Virus

# %%
anuj.work
# Out:
# 45

# %%
ruby.work
# Out:
# 40

# %%
ruby.work = 30

# %%
ruby.work
# Out:
# 30

# %%
employee.work=45

# %%
ruby.work
# Out:
# 30

# %%
ruby=employee()

# %%
ruby.work
# Out:
# 30

# %% [markdown]
# ### Database connectivity

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost', database = 'dmart', user='root', passwd = 'MySQL@2021')

# %%
c= conn.cursor(buffered=True)

# %%
class employee:
    work = 40
    def __init__(self, emp_name, password):
        print("Initialising the class")
        self.emp_name=emp_name
        self.password = password
        print(emp_name, password)
        
        stmt = "select count(*) from customer where cname = '{}'" 
        stmt= stmt +"and mobile_number= '{}';".format(self.emp_name,self.password)
        print(stmt)
        c.execute(stmt)
        rec = c.fetchall()
        print(rec)
        val = rec[0][0]
        print(val)
        #val=False
        if val==1 :
            print("Valid user")
            print('call the user page')
        else:
            print("INVALID USER")
            raise Exception("not valid user")
                
        
    
    def calc_salry(self, user):
        print("Calculating salary ")

    def apply_leaves(self):
        print("enter leaves here. call the page and tem view for reco")
        tup=('leave')
        ##print('insert stmt tuple')
        return tup
    
    def confirm_leaves(self, ltup):
        print('insert ltup')
        print('commit')

    def leave_view():

# %%
e=employee('ABCD','0987654321')
# Out:
# Initialising the class
# ABCD 0987654321
# select count(*) from customer where cname = 'ABCD' and mobile_number= '0987654321';
# [(1,)]
# 1
# Valid user

# %%
rec = [(1,)]

# %%
rec[0][0]
# Out:
# 1

# %%
e.calc_salry()
# Out:
# Calculating salary

# %%
a1 = employee("ANIKET",'9898989898')
# Out:
# Initialising the class
# ANIKET 9898989898
# select count(*) from customer where cname = 'ANIKET' and mobile_number= '9898989898';
# [(1,)]
# 1
# Valid user

# %%
e1= employee('sjfkg','384907')
# Out:
# Initialising the class
# sjfkg 384907
# select count(*) from customer where cname = 'sjfkg' and mobile_number= '384907';
# [(0,)]
# 0
# INVALID USER
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-a96e3c82532b> in <module>
# ----> 1 e1= employee('sjfkg','384907')
#
# <ipython-input-12-eec64334745d> in __init__(self, emp_name, password)
#      19         else:
#      20             print("INVALID USER")
# ---> 21             raise Exception()
#      22
#      23
#
# Exception:

# %%
try:
    e1= employee('sjfkg','384907')
except:
    print("Not a valid user name and password")
# Out:
# Initialising the class
# sjfkg 384907
# select count(*) from customer where cname = 'sjfkg' and mobile_number= '384907';
# [(0,)]
# 0
# INVALID USER
# Not a valid user name and password

# %%
e1.calc_salry()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bd332f79b643> in <module>
# ----> 1 e1.calc_salry()
#
# NameError: name 'e1' is not defined

# %%
e2 = employee('anita','9090909090')
# Out:
# Initialising the class
# anita 9090909090
# select count(*) from customer where cname = 'anita' and mobile_number= '9090909090';
# 1
# Valid user
